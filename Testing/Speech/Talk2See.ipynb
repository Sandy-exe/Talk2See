# %%
# !pip install numpy
# !pip install gtts

# %%
# !pip install openai==0.28
# !pip install kaleido
# !pip install cohere

# !pip install typing_extensions

# !pip install -q openai-whisper
# !pip install -q gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 52.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 15.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 76.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 76.9 MB/s eta 0:00:00
# ...

# %%
import whisper
import gradio as gr
import openai
from gtts import gTTS

# %%
model = whisper.load_model("base")
openai.api_key = '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'
#openai.api_key = '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'
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:02<00:00, 61.7MiB/s]

# %%
text_to_speak = "Hello, this is a sample text to convert to speech."

# Create gTTS object
tts = gTTS(text=text_to_speak, lang='en')

# Save the speech as a WAV file
tts.save("output.wav")

from IPython.display import Audio, display

display(Audio('output.wav', autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from transformers import pipeline

p = pipeline("automatic-speech-recognition", model="Santhosh-kumar/ASR")

import gradio as gr
from transformers import pipeline
import numpy as np

transcriber = pipeline("automatic-speech-recognition", model="Santhosh-kumar/ASR")

def transcribe(audio):
    if audio == None:
      return ["Try Again","Try Again","output.wav"]
    sr, y = audio
    y = y.astype(np.float32)
    y /= np.max(np.abs(y))

    input_text = transcriber({"sampling_rate": sr, "raw": y})["text"]

    messages = [
    {"role": "system", "content": "You are a helpful assistant."}]

    if input_text:
        messages.append(
            {"role": "user", "content": "Guide the user however he/she wants."+input_text},
        )
        chat_completion = openai.ChatCompletion.create(
            model="gpt-3.5-turbo", messages=messages
        )
    reply = chat_completion.choices[0].message.content
    tts = gTTS(text=reply, lang='en')
    # Save the speech as a WAV file
    tts.save("output.wav")
    return(input_text,reply, 'output.wav')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.83k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# ...

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline
pipe = pipeline("automatic-speech-recognition", model="Santhosh-kumar/ASR")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
text_reply = gr.Textbox(label="Corrected Text")
voice_reply = gr.Audio('output.wav')
stt_input = gr.Textbox(label="Speech to Text")

demo = gr.Interface(
    title = 'Talk2See',
    fn=transcribe,
    inputs=[
        gr.Audio(sources=["microphone"]),
    ],

    outputs=[
        stt_input, text_reply,  voice_reply
    ], )
demo.launch(debug=True,share=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://c38cac0d9da8320191.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c38cac0d9da8320191.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/protocols/http/h11_impl.py", line 407, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     return await self.app(scope, receive, send)
# ...

# %%
# Define your function
def my_function(input_audio):
    # Your code here
    pass

# Define your inputs and outputs
input_audio = gr.Audio(sources=["microphone"], label="Input Audio")
output_text = gr.Textbox(label="Output Text")
output_audio = gr.Audio('output.wav', label="Output Audio")

# Create the interface
demo = gr.Interface(
    fn=my_function,  # Use your function
    title='My Interface',
    inputs=[input_audio],
    outputs=[output_text, output_audio],
)

# Deploy the interface
demo.launch()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-b6614034fd2b> in <cell line: 20>()
#      18
#      19 # Deploy the interface
# ---> 20 demo.deploy("my_interface")
#
# AttributeError: 'Interface' object has no attribute 'deploy'

# %%
import gradio as gr
print(gr.__version__)
# Out:
# 4.16.0
